# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Distribution Plots
# - distplot
# - joinplot
# - pairplot

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ## Correlation with Heatmap
# - A correlation heatmap uses colored cells, typically in a monochromatic scale, to show a 2D correlation matrix (table) between two discrete dimensions of event types. It is very important in Feature Selecion. Correlation can be only found in float and int values

# %%
## get only the numeric data 
numeric_corr = df.select_dtypes(include=['number'])

# %%
corr = numeric_corr.corr()

# %%
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## JointPlot

# %% [markdown]
# - A jointplot allows to study the relationship between 2 numeric variables. The central chart display their correlation. It is usually a scatterplot, a hexbin plot, a 2D histogram or a 2D density plot

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.jointplot(x='tip',y='total_bill', data=df, kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill', data=df, kind='reg')

# %% [markdown]
# ## Pair Plot

# %% [markdown]
# - A "pair plot" is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# ## Dist Plot
# - Dist Plot helps us to check the distribution of the columns feature

# %%
sns.displot(df['tip'],kde=True)

# %%
sns.displot(df['tip'],kde=False,bins=10)

# %% [markdown]
# ## Categorical Plots

# %% [markdown]
# - Seaborn also helps us in doing the analysis on Categorical Data Points.
# - * boxplot
#   * violinplot
#   * countplot
#   * bar plot

# %%
## Count Plot

sns.countplot(x='sex',data=df)
#represents the total count of a specific category
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
## Bar Plot
## In Bar plot we have to specify both x:axis and y:axis

sns.barplot(y='total_bill',x='sex', data=df,hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Box Plot

# %% [markdown]
# - A box plot and whisker plot (sometimes called a boxplot) is a graph that presents information from a five-number summary

# %%
sns.boxplot(x='sex',y='total_bill', data=df,hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill', data=df,hue='day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Gets all the features and plots a boxplot (Percantile diagram)
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >

# %%
# Categorize the data based on same other categories
sns.boxplot(x='total_bill',y='day', hue='smoker', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# - Violin Plot helps us to see both distribution of data in terms of Kernel Density Estimation and the box plot

# %%
sns.violinplot(x="total_bill",y="day",data=df,hue="day", legend=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
